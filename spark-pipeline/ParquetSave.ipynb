# %%
import findspark
findspark.init('/home/hadoop/spark-2.2.2-bin-hadoop2.7')
from pyspark import SparkContext, SparkConf
from pyspark.sql import SQLContext
conf = SparkConf().setAppName("miniProject").setMaster("spark://master:7077")
sc = SparkContext(conf=conf)
sqlcontext = SQLContext(sc)

# %%
class MaxScoreTokenizer:
    """Soynlp Maxscore Tokenizer: origin https://github.com/lovit/soynlp"""
    def __init__(self, scores=None, max_length=10, default_score=0.0):
        self._scores = scores if scores else {}
        self._max_length = max_length
        self._ds = default_score

    def __call__(self, sentence, flatten=True):
        return self.tokenize(sentence, flatten)

    def tokenize(self, sentence, flatten=True):
        tokens = [self._recursive_tokenize(token) for token in sentence.split()]
        if flatten:
            tokens = [subtoken[0] for token in tokens for subtoken in token]
        return tokens

    def _recursive_tokenize(self, token, range_l=0, debug=False):
        
        length = len(token)
        if length <= 2:
            return [(token, 0, length, self._ds, length)]

        if range_l == 0:
            range_l = min(self._max_length, length)

        scores = self._initialize(token, range_l, length)
        if debug:
            pprint(scores)
        
        result = self._find(scores)
        
        adds = self._add_inter_subtokens(token, result)
        
        if result[-1][2] != length:
            adds += self._add_last_subtoken(token, result)
            
        if result[0][1] != 0:
            adds += self._add_first_subtoken(token, result)
            
        return sorted(result + adds, key=lambda x:x[1])

    def _initialize(self, token, range_l, length):
        scores = []
        for b in range(0, length - 1):
            for r in range(2, range_l + 1):
                e = b + r
                
                if e > length: 
                    continue
                
                subtoken = token[b:e]
                score = self._scores.get(subtoken, self._ds)
                scores.append((subtoken, b, e, score, r))
                
        return sorted(scores, key=lambda x:(-x[3], -x[4], x[1]))

    def _find(self, scores):
        result = []
        num_iter = 0
        
        while scores:
            word, b, e, score, r = scores.pop(0)
            result.append((word, b, e, score, r))

            if not scores:
                break

            removals = []
            for i, (_1, b_, e_, _2, _3) in enumerate(scores):
                if (b_ < e and b < e_) or (b_ < e and e_ > b):
                    removals.append(i)

            for i in reversed(removals):
                del scores[i]

            num_iter += 1
            if num_iter > 100: break

        return sorted(result, key=lambda x:x[1])
    
    def _add_inter_subtokens(self, token, result):
        adds = []        
        for i, base in enumerate(result[:-1]):
            if base[2] == result[i+1][1]:
                continue
            
            b = base[2]
            e = result[i+1][1]
            subtoken = token[b:e]
            adds.append((subtoken, b, e, self._ds, e - b))
        
        return adds

    def _add_first_subtoken(self, token, result):
        e = result[0][1]
        subtoken = token[0:e]
        score = self._scores.get(subtoken, self._ds)
        return [(subtoken, 0, e, score, e)]
    
    def _add_last_subtoken(self, token, result):
        b = result[-1][2]
        subtoken = token[b:]
        score = self._scores.get(subtoken, self._ds)
        return [(subtoken, b, len(token), score, len(subtoken))]

from hdfs import InsecureClient
import json
client_hdfs = InsecureClient('http://master:50070')

# %%
with client_hdfs.read('/user/hadoop/scores.json', encoding = 'utf-8') as score_json:
    scores = json.load(score_json)
tokenizer = MaxScoreTokenizer(scores=scores)

# %%
scores
# Out:
# {'마피아': 0.20434891103829422,
#  '별점테러하지': 0.4235297767094588,
#  '싸가지없': 0.34919048178905,
#  '이작품이': 0.17811735527464292,
#  '작가님이': 2.4564077346254667,
#  '고무고무': 0.27195361489510117,
#  '딩동이': 1.3670551036019707,
#  '킹메': 0.1266130832232532,
#  '있다니': 0.31776686243787294,
#  '막컷의': 0.19984585807347613,
#  '무섭지': 0.18178197883655792,
#  '믿는다': 0.6722550930486331,
#  '우디르급': 0.1,
#  '왼손잡이': 0.1,
#  '보여주고싶': 0.1,
#  '없나요': 0.3855053128390623,
#  '주인한테': 0.3144527019383392,
#  '출근하는': 0.4110589446144157,
#  '아테나의': 0.23937545484932043,
#  '살아': 0.8583299461162326,
#  '댕댕': 0.1,
#  '어이없어서': 0.4590750865054275,
#  '위주로': 0.31877602398948546,
#  '죽였는': 0.1,
#  '맴도': 0.1,
#  '걸렸습': 0.1,
#  '마조히스': 0.1,
#  '에너지를': 0.7756596902764186,
#  '싫어하시는': 0.18409901877645407,
#  '동의하지': 0.15724950374759297,
#  '사랑해주세': 0.1,
#  '모르지': 0.23763103341663508,
#  '어쩌구저쩌구': 0.3305037967005815,
#  '버튼을': 0.22489245256502194,
#  '솔직하고': 0.36685630302743955,
#  '따라했': 0.1,
#  '익숙해졌': 0.1,
#  '칼리': 0.3465714457958713,
#  '살아왔': 0.21618443937034837,
#  '마음의소리에': 0.1,
#  '다니는': 0.5653651431289841,
#  '지금': 1.438847821487352,
#  '광고도': 0.24197706585694778,
#  '많으시네': 0.14328338349522052,
#  '발휘하': 0.1,
#  '써서라도': 0.21070647180980273,
#  '아름다': 0.17343844778840756,
#  '와미친': 0.17701948128075315,
#  '소름': 0.3885552829400214,
#  '문제인가': 0.2318956958437493,
#  '있었던일': 0.1,
#  '민디민': 0.1,
#  '순간': 1.5167635469977283,
#  '좀비딸': 0.32831798960720543,
#  '기억을': 0.5309431809873718,
#  '엔즈가': 0.9380199307110909,
#  '생각난건': 0.16465981450102052,
#  '추이에': 0.1251808147627026,
#  '분위': 0.1,
#  '젖은': 0.5845270086720569,
#  '알고있을': 0.22286736696564896,
#  '소티스랑': 0.20059713454489797,
#  '빠른데': 0.21767100656046523,
#  '일상생활이': 0.3331158403910959,
#  '의심되는': 0.2936098803060354,
#  '그것도': 0.4738171065855272,
#  '못받는': 0.20446128843715414,
#  '방해되': 0.1,
#  '펭러메': 1.1749048969355318,
#  '이기는게': 0.20102430446824468,
#  '베댓아': 0.611913477361076,
#  '소중함을': 0.36042205427083085,
#  '도와주겠': 0.1,
#  '마음으': 0.1,
#  '넘어가주': 0.1,
#  '최종적으': 0.1,
#  '무슨짓을': 0.31826450007683726,
#  '다르게': 0.6062363585857733,
#  '하나같이': 0.576382460353323,
#  '없겠지': 0.23293614834694223,
#  '언급할': 0.16701223632988782,
#  '같은데그': 0.1,
#  '경로를': 0.13841395646387453,
#  '말했어요': 0.29453310089252593,
#  '권력을': 0.869975543125822,
#  '착하긴': 0.20868763021701503,
#  '섹드립': 0.6971424351357545,
#  '프로토': 0.1,
#  '무한에너지': 0.1,
#  '쌘놈': 0.1,
#  '시험문제': 0.1,
#  '무시할수': 0.14468566417000445,
#  '탄탄해': 0.13227785846232754,
#  '적이라': 0.29470167720585766,
#  '함정카': 0.1,
#  '스포심하거든요': 0.1,
#  '장담하': 0.1,
#  '윈지': 0.1,
#  '상처받을': 0.3058552736232843,
#  '특별편': 0.5390018387183966,
#  '멋져보이': 0.1,
#  '깔끔': 0.43628278012287225,
#  '어필하는': 0.14996532185022032,
#  '안할수가': 0.12811906328451514,
#  '보고싶었는데': 0.5083256296675611,
#  '단행본으로': 0.530213716513879,
#  '정체불명의': 0.2947454925156934,
#  '요구르': 0.1,
#  '점심시간에': 0.2772087293046832,
#  '한결같은': 0.3148451387523195,
#  '비교해서': 0.4391128556213112,
#  '죽는다고': 0.49114081400994414,
#  '핑크머': 0.1,
#  '구분못': 0.1,
#  '줄여서': 0.6383047382602732,
#  '자연분만': 0.1,
#  '꺄아아아아아아': 0.1,
#  '끄집어내': 0.1,
#  '나가는': 0.45246197829595125,
#  '신박하다': 0.33947735888978836,
#  '맨몸으': 0.1,
#  '뒤지지': 0.11954138937321013,
#  '벗겨': 0.26944565265690484,
#  '기억해': 0.2887610436177386,
#  '배댓': 1.0160812816713451,
#  '모두들': 0.36630616736657484,
#  '단건우': 0.39810864370535537,
#  '조선왕조실': 0.2666690625533332,
#  '출근하면': 0.2234727610950937,
#  '상황이지': 0.2514403231504142,
#  '외부에서': 0.19789920939863592,
#  '계약한': 0.20472945137301185,
#  '집행위': 0.1,
#  '청소년': 0.9896391653201205,
#  '배신때': 0.1,
#  '할머니댁': 0.1,
#  '무서웠을': 0.1590365411318395,
#  '응급': 0.15864829395422955,
#  '사망플래그': 0.7543670986657764,
#  '넘귀엽': 0.1,
#  '해야겠어': 0.1617213088843352,
#  '죽은': 0.4638806041720388,
#  '살아남지': 0.13362743650800163,
#  '귀여우신': 0.37417294935196466,
#  '무서운건': 0.5604637636154912,
#  '관점으로': 0.3109660125144815,
#  '노예가': 0.20025591587625613,
#  '삼계탕': 0.1,
#  '낳으': 0.15679111233507087,
#  '욕하네': 0.26014153683608093,
#  '우리들도': 0.1587807226527624,
#  '땡전이': 1.4296542358102644,
#  '묶여서': 0.2779119280104877,
#  '훔쳤': 0.1,
#  '비스무리': 0.15351200291388173,
#  '커맨드': 0.1393533068089698,
#  '알아보고': 0.7399218152197095,
#  '블러드': 0.4672519572705791,
#  '급식들아': 0.2975843277447936,
#  '파악하지': 0.13802929904491826,
#  '충격먹어': 0.1,
#  '미카엘': 0.24987013150145912,
#  '뺑소': 0.1,
#  '배경에': 0.2455019258468449,
#  '머리자': 0.1,
#  '에브라': 0.11063458884140741,
#  '활동이': 0.31547432548153226,
#  '여성부는': 0.3543652194324578,
#  '이후로는': 0.22873771844176252,
#  '흉허복': 0.1,
#  '말하는거보': 0.1,
#  '먹는사람': 0.25819907361376615,
#  '카사크': 0.35316528422655635,
#  '엄마와': 0.3672239083733789,
#  '웃음만': 0.1,
#  '집어넣어': 0.1,
#  '좋아했었는': 0.1,
#  '였던거': 0.30431369569479455,
#  '욕하는지': 0.2603968965012743,
#  '편이다': 0.24400282300274445,
#  '씁니': 0.1,
#  '토닥여': 0.1,
#  '스프라이': 0.1,
#  '김가을': 0.30444581178073493,
#  '알아야한다': 0.3964134479587902,
#  '선택지': 0.15562270013075946,
#  '놀이공원': 0.29469943991792574,
#  '뭉치': 0.17277111721612065,
#  '집중하라': 0.1,
#  '휴대폰으': 0.1,
#  '기대하지': 0.20184582386428213,
#  '찍는거': 0.3708874967064347,
#  '수고하셨습니': 0.13081405874698426,
#  '여자지만': 0.4036008213032872,
#  '시키는게': 0.4112267850627498,
#  '된다니': 0.3552565057423157,
#  '익히고': 0.3007959137492411,
#  '생각안하고': 0.6234950438157725,
#  '너무싫어': 0.1,
#  '단어가': 0.5505903263364031,
#  '힘내세여': 0.20094557425279105,
#  '벗어난': 0.817901442621958,
#  '우는거': 0.376390700618662,
#  '곽백': 0.1,
#  '예쁘지': 0.17300194275093467,
#  '중앙기사단': 0.1,
#  '진행하면': 0.21361210929167576,
#  '최강자전때': 0.3662216325634984,
#  '책임감있': 0.1,
#  '드림코퍼레이션': 0.5191188715935916,
#  '뒤쳐지': 0.1,
#  '클린하': 0.1,
#  '끈을': 0.2516029985147964,
#  '카운트': 0.1,
#  '제국주의': 0.2183102144842669,
#  '받아들이고': 0.9768368200259313,
#  '큐브': 0.7081036464752227,
#  '작정하고': 0.37190459747272475,
#  '빨개진': 0.25073165759788213,
#  '떡밥일': 0.2833076150589221,
#  '부탁드립': 0.1,
#  '수업시간에': 0.8381078195432746,
#  '애봉이가': 0.5366031918239114,
#  '뒤지고': 0.24709122087322336,
#  '올려도': 0.22273213264062203,
#  '도덕적으': 0.1,
#  '오라오라오라오라오': 0.1,
#  '고생하시는': 0.5758270419153398,
#  '누나랑': 0.22663846222599615,
#  '취급하면': 0.1,
#  '베댓되려': 0.1,
#  '마아트가': 0.2548333052644179,
#  '밑으로': 0.7424693362267185,
#  '어렵다고': 0.32059968743771744,
#  '흥미진': 0.1,
#  '채색이': 0.29057312363241433,
#  '따라다': 0.1,
#  '파이팅하': 0.1,
#  '수영장에': 0.1843963706147938,
#  '있었구나': 0.5291877672133106,
#  '돈때문에': 0.46872506093808375,
#  '살아갈': 0.29592906665267704,
#  '왜이러지': 0.3651515993050407,
#  '인간들에게': 0.579230153708026,
#  '환호하': 0.1,
#  '현재로': 0.1981547361897062,
#  '웹툰을': 1.2753172811118902,
#  '투니버': 0.1,
#  '하스티가': 0.24539223040366168,
#  '옷도': 0.3152860564699941,
#  '벤자': 0.1,
#  '잘못알': 0.1,
#  '자주하는': 0.1456768813913079,
#  '늦는건': 0.33141036656957423,
#  '거리가': 0.33438808742648346,
#  '정주행해보': 0.1,
#  '선생들': 0.14398418912608568,
#  '안이어지': 0.1,
#  '상황에': 0.6238650547449214,
#  '되는겁니': 0.1,
#  '찌질해': 0.18843624455966435,
#  '등장해': 0.13423775762102186,
#  '옥상에서': 1.176220909974686,
#  '견디고': 0.32707132201958067,
#  '오징어': 0.2899115818175233,
#  '추기경이': 0.2680653074342603,
#  '세월호가': 0.25999187676534236,
#  '센스쟁': 0.1,
#  '먹잇감': 0.1,
#  '숫자에': 0.24501654250501306,
#  '세뇌시키': 0.1,
#  '게으르': 0.1,
#  '부끄러운': 0.4476623308391189,
#  '모양인데': 0.35568955386626133,
#  '왕권을': 0.2604671985630359,
#  '희망이라': 0.1,
#  '쪼꼬': 0.1,
#  '앞장서서': 0.19567395659398557,
#  '힐리스도': 0.5077429182125197,
#  '너무하네요': 0.25188448779056694,
#  '살아있는게': 0.4622301190824418,
#  '앉아있는거': 0.43264434350363457,
#  '시나리': 0.1,
#  '잃은것': 0.1,
#  '붙어서': 0.8658884221937565,
#  '엉클': 0.4481996614908025,
#  '커플티': 0.1,
#  '파괴력': 0.1,
#  '샀는데': 1.4673019643786431,
#  '캐릭터들을': 0.7769844325285602,
#  '작가들에': 0.12878905993977036,
#  '변해있': 0.1,
#  '앞자리': 0.21064272649239765,
#  '저렇게라도': 0.41081230362357324,
#  '올렸다': 0.27246165328965277,
#  '진심어린': 0.27252105452695735,
#  '왕자': 0.7535361246650173,
#  '란에게': 0.46868546489291496,
#  '여자친구한테': 0.38018150629374436,
#  '세상에는': 0.4214896164668488,
#  '힘들겠다': 0.40580580715419257,
#  '저번화를': 0.14772451200232098,
#  '양호선': 0.1,
#  '자살하게': 0.15398969625752726,
#  '압축해': 0.1,
#  '사랑하는거': 0.3019418399092644,
#  '구분이': 0.26568101559310686,
#  '하셨습니다': 0.8727345351857722,
#  '별로없': 0.1,
#  '한번쯤은': 0.46604064624415864,
#  '노는게': 0.22382628118193004,
#  '믿고있었': 0.1,
#  '둬서': 1.1049869521082085,
#  '양민우': 0.13685893347983802,
#  '될거같': 0.38109257417279385,
#  '얼마전까': 0.1,
#  '해야되는': 0.3752615183436877,
#  '작업하는': 0.1462554771135271,
#  '작가님힘내세요쉬세요': 0.1,
#  '디스하': 0.1,
#  '사이에선': 0.1646368359232298,
#  '상대하려': 0.1,
#  '혼란해': 0.12423955432938386,
#  '로리카': 0.14379012651485992,
#  '메브의': 0.3313322405810072,
#  '겐조주니': 0.1,
#  '친구라고': 0.6921296705707843,
#  '불안하게': 0.39560051752895486,
#  '나라에': 0.28405607402211536,
#  '이후로': 0.35004886872541086,
#  '엄마의': 0.6650322631048402,
#  '규정': 0.24088154668106468,
#  '쓰레기': 1.7960088967379655,
#  '장기자랑': 0.18035869971577403,
#  '좋으니': 0.28411827306382786,
#  '생각못하': 0.1,
#  '기술이라': 0.1910833228325697,
#  '어쩔수없이': 0.8719993041634445,
#  '없어지지': 0.11987889889592052,
#  '왜일까': 0.17796109250598707,
#  '무적핑크': 0.16623508152780325,
#  '조곤조곤': 0.18692627162979286,
#  '양형의': 0.6064462938022289,
#  '새키들': 0.2082122840026166,
#  '주인공이니': 0.140383661036985,
#  '콘푸로스트': 0.5752695219781342,
#  '걸릴거': 0.1,
#  '옷벗고': 0.2573517706634856,
#  '귀여워라': 0.3502070979598818,
#  '외로울': 0.13986292326294458,
#  '얍삽': 0.1,
#  '스마트폰이': 0.4448124045893481,
#  '박차는': 0.2355478454140914,
#  '도망가': 0.37158585896722873,
#  '군대': 1.587220469993681,
#  '한국인이라': 0.1,
#  '작가님제': 0.1,
#  '죽을것이': 0.1,
#  '정도였는': 0.1,
#  '사이에는': 0.20572340012834117,
#  '잘보고있어': 0.1,
#  '다녀오겠습니다': 0.6614342434027366,
#  '죽어가고': 0.1255309908387257,
#  '잃어버린': 1.6217291973116033,
#  '허락도': 0.17277265650447002,
#  '썩어빠진': 0.8581513588796188,
#  '여러분들': 0.7856960525892354,
#  '변한': 0.27692610321355815,
#  '외계인을': 0.34304373478345507,
#  '대학교': 0.4019072519816922,
#  '빠지겠': 0.1,
#  '잊을': 0.19321791536655114,
#  '징그': 0.23701748916327908,
#  '대화하': 0.16555420294748968,
#  '있다니까': 0.24478260435003915,
#  '환자를': 0.3948475263348903,
#  '후반부에': 0.40848557461697244,
#  '여성으로': 0.24277830050590976,
#  '오래동안': 0.2574770286308507,
#  '단편적': 0.14644371754092292,
#  '안전벨트': 0.2829398056728021,
#  '울었어': 0.20915074215846247,
#  '무서워했': 0.1,
#  '대사': 0.33071320852041775,
#  '시작하시': 0.1,
#  '들어온사람': 0.5070752684146106,
#  '기다려': 0.5820520801323419,
#  '빨려들': 0.1,
#  '쌍욕을': 0.40145317405112013,
#  '얻었습니다': 0.6194990580207049,
#  '백만원': 0.2748981467131134,
#  '긔여워': 0.6773078682705143,
#  '역사적으로': 0.5829637188453649,
#  '멋지세요': 0.3029216402904065,
#  '찡했': 0.1,
#  '예정이라': 0.1,
#  '욕하면서': 1.0799187887690258,
#  '작가님사랑': 0.1,
#  '들어주세요': 1.1338360140851007,
#  '암묵적으': 0.1,
#  '서유기에': 0.26385153425419283,
#  '겁니까': 0.707255287825882,
#  '따지지': 0.1999183274112239,
#  '깨어': 0.24527768922824245,
#  '바른연애': 0.1,
#  '공부하다가': 0.484124060351696,
#  '별점테러하고': 0.5479504634713321,
#  '심해지면': 0.30940216386686714,
#  '필요합니': 0.1,
#  '전자레인지에': 0.4846430127563687,
#  '싫어하게': 0.365185308579146,
#  '중요한게': 0.288011867984054,
#  '마음입니': 0.1,
#  '들어': 2.0467270033245755,
#  '허전해': 0.13962321256237104,
#  '못이기': 0.1,
#  '달리기': 0.36963843181817535,
#  '못했네요': 0.3567573758654893,
#  '돼지라': 0.15903859324270792,
#  '남자선배': 0.1,
#  '쏟아내': 0.1,
#  '표정봐': 0.3509570511347193,
#  '목표인': 0.13843069996340962,
#  '냄새도': 0.47165215312267916,
#  '회색머': 0.1,
#  '숨기고있': 0.1,
#  '자기때문': 0.1,
#  '프시히는': 0.619566772867654,
#  '불가살': 0.3182108294698276,
#  '기대하고있': 0.1,
#  '방해한': 0.13240191555670855,
#  '바로잡': 0.14451155083549833,
#  '포고님': 0.16201010113219919,
#  '다시보게': 0.19520120460634727,
#  '무너져내': 0.1,
#  '귀찮아': 0.21055864417442283,
#  '우리오파': 0.1,
#  '쿵쾅쿵': 0.1,
#  '표정봨': 0.1,
#  '난리나': 0.1,
#  '그런거잖': 0.1,
#  '재연재': 0.31544697606613437,
#  '감성적인': 0.30102656968118713,
#  '버일러': 0.23210784257428346,
#  '곽보경': 0.9703608916737572,
#  '해야': 0.45013737652760777,
#  '대하다추현': 0.1,
#  '알아야합': 0.1,
#  '웹툰계에': 0.21971121090512044,
#  '쫄아서': 1.2783865291169854,
#  '신이시여': 0.1987101538737463,
#  '간접적': 0.11571826307296916,
#  '파괴되': 0.1,
#  '배고프다': 0.19688987429046695,
#  '병맛같': 0.1,
#  '로맨': 0.16711775694384512,
#  '권력으': 0.1,
#  '멀쩡할': 0.24347733827577656,
#  '철없는': 0.6398591237606992,
#  '실눈캐가': 0.1,
#  '되는것도': 0.3075479592506004,
#  '산소를': 0.1833736959262826,
#  '낢이사는이야': 0.1,
#  '몇년뒤': 0.1,
#  '운이형': 0.18647478656270525,
#  '위험한거': 0.20416833981625776,
#  '상상이상': 0.1,
#  '릴리아도': 0.4955977330142467,
#  '불가능': 0.5634475361100427,
#  '후손들': 0.11843800218467823,
#  '드레곤': 0.13604815802382994,
#  '년후에': 0.28729652830648367,
#  '첫베': 0.11690963717640665,
#  '가슴을': 0.28453218275860326,
#  '할수있습니': 0.1,
#  '블랙코': 0.1,
#  '슬펐어요': 0.3320719089597508,
#  '컴퓨터에': 0.8844818625673193,
#  '웹툰이었': 0.1,
#  '산군이': 0.7375562264051793,
#  '군대는': 0.5891364791499308,
#  '펜타호': 0.1,
#  '분명하': 0.17605601174730445,
#  '감사하다': 0.36238299166275345,
#  '에이': 0.45541730348744447,
#  '텍스트': 0.1,
#  '구상룡': 0.18870373755483863,
#  '안녕하십': 0.1,
#  '기대되': 0.20060043201540684,
#  '어려서부터': 0.48018529798420395,
#  '환영': 0.19070299264732177,
#  '무시하면서': 0.26153343295887943,
#  '웃긴게': 0.5549326693463914,
#  '산업스파이': 0.3153150518286376,
#  '사랑해주셔': 0.1,
#  '아저씨한': 0.1,
#  '헌팅': 0.1,
#  '받아들이지': 0.38498466066285075,
#  '했을텐': 0.1,
#  '효림': 0.1,
#  '되더라구': 0.1,
#  '캉타우': 2.667711134280265,
#  '느껴진다고': 0.42109730655566224,
#  '알겠습니': 0.1,
#  '그림체는': 0.5914972698882244,
#  '머리아': 0.1,
#  '연재하시느라': 0.48626622096018446,
#  '영국인': 0.1,
#  '포함해서': 0.756681985981485,
#  '얻어먹고': 0.3773567498165863,
#  '코피가': 0.21877942024367347,
#  '첫번째베': 0.1,
#  '트리니티': 0.3051530371562207,
#  '돼지가': 0.8142792473461113,
#  '불가살이': 0.5543310583281371,
#  '참는다': 0.25435389039516854,
#  '존중해주': 0.1,
#  '자까님은': 0.13942465583681624,
#  '실수해': 0.1,
#  '추천드립니': 0.1,
#  '응원하겠습': 0.1,
#  '생각하기에': 0.4424448471450716,
#  '만들수': 0.15424757355972052,
#  '그런거같': 0.1,
#  '메테우스가': 0.6430982620054823,
#  '처음만': 0.12502197134879772,
#  '요즘은': 1.189323469452773,
#  '만큼이나': 0.35500577665510125,
#  '자각하고': 0.18541481468355395,
#  '짱가는': 0.45123351196130124,
#  '왓이프': 0.2519558548897196,
#  '길고양': 0.1,
#  '이름이라': 0.16854077411499407,
#  '죽은사람': 0.25633644994878574,
#  '떼쓰는': 0.3010523737961691,
#  '많으니까': 0.6069162965751334,
#  '망상에': 0.20696875002201928,
#  '관심있': 0.17097790784807648,
#  '떡볶이': 0.7936588096635216,
#  '모나작가님': 0.3056263084879164,
#  '열었는': 0.1,
#  '야와는': 0.26925209805022887,
#  '말하니까': 0.4879380254893749,
#  '뒷걸음': 0.1,
#  '선물로': 0.3448608880904812,
#  '창피해': 0.26533268545638866,
#  '결혼한거': 0.21188169861252287,
#  '민호가': 0.4527044998686687,
#  '자림이랑': 0.3951128711930444,
#  '성지가': 0.16312481478013818,
#  '기다려져요': 0.32968043501702066,
#  '태형이': 0.33051257345273494,
#  '훈련소에': 0.1,
#  '꼬부기': 0.19328420219708498,
#  '형태': 0.20423151832789438,
#  '임신한': 0.3397057059316836,
#  '쟤네': 0.9345571988206662,
#  '시스템': 0.3689653759477256,
#  '각오로': 0.257281140593662,
#  '한사람은': 0.34893738967671356,
#  '지은이를': 0.21535409117328325,
#  '지난번': 0.1813146378228604,
#  '가우스전자': 0.7439318412287771,
#  '빼놓고': 0.30776078279481656,
#  '먹먹해지': 0.1,
#  '명언이다': 0.7383335759691804,
#  '심화연': 0.22893917495107793,
#  '재인이': 0.22324538500973684,
#  '한도가초과되었': 0.1,
#  '들어가요': 0.3293498156755572,
#  '행복합니': 0.1,
#  '두드러': 0.1,
#  '조금씩': 0.8173146098699186,
#  '상사에게': 0.22516929664176294,
#  '알고계': 0.13520388299574487,
#  '올라온다': 0.20153533338881707,
#  '팬이라고': 0.39860141663924675,
#  '운동신경': 0.281728307111362,
#  '예상했': 0.2305802885973185,
#  '모아서': 0.37759583300999333,
#  '하잖아요': 0.45221151700339923,
#  '휴지가': 0.30188531608321073,
#  '않는건가': 0.22133597990641674,
#  '빛나': 0.5505956168014703,
#  '색다르': 0.1,
#  '멍멍이': 0.6052213952929342,
#  '하나때문에': 0.4753405226080746,
#  '직원들': 0.6846979230545825,
#  '쯤이': 0.2209002994627407,
#  '상처를': 0.5127605509234345,
#  '우물쭈물': 0.1,
#  '승승장': 0.1,
#  '꽃이라': 0.1,
#  '줍는': 0.30413452698399546,
#  '성공한': 0.42287513002082544,
#  '해피앤딩': 0.1,
#  '추천드립니다': 0.8660337879435009,
#  '플랫폼에': 0.2325610653790106,
#  '밟았': 0.1,
#  '가족들이랑': 0.4345246820690014,
#  '양판소': 0.15740434825976785,
#  '옷에': 0.39190670900392166,
#  '저정도는': 0.2985830416562697,
#  '뇌를': 0.47268860236852284,
#  '석호': 0.4528402591763373,
#  '늑대를': 0.5598518457033743,
#  '오해하게': 0.16162323510541224,
#  '해주는거': 0.4158745435759773,
#  '그에비해': 0.19074939531824647,
#  '매화마': 0.1,
#  '들이밀': 0.11225085767594971,
#  '윈터': 0.14040465646327013,
#  '떨어트려': 0.1,
#  '웹툰인듯': 0.23083777823581936,
#  '넘어가겠': 0.1,
#  '격투': 0.31282650479540935,
#  '망했으면': 0.23879678153580172,
#  '웬만해선': 0.6621499939719401,
#  '보러왔습니다': 0.6978339863865357,
#  '해피엔딩인': 0.1,
#  '그거가지고': 0.4229960100369887,
#  '들어오': 0.5857157693770672,
#  '쩌네요': 0.5372748650622812,
#  '밉보': 0.1,
#  '죽이지않': 0.1,
#  '직장생활': 0.3752121842570807,
#  '맨처음에': 0.5843219789543871,
#  '놀래키': 0.1,
#  '매회마다': 0.3732743712721006,
#  '탐관오': 0.1,
#  '담당자는': 0.4005606114570063,
#  '참전용사분': 0.1,
#  '우연이': 0.4153582736062802,
#  '따라한다': 0.1,
#  '아버지한테': 0.5841661439323862,
#  '잡혀가': 0.12607595201836083,
#  '중학교에': 0.2912530294375773,
#  '와닿네': 0.11609259533533314,
#  '밖에나가': 0.1,
#  '뻔해서': 0.3856501962018747,
#  '나오길래': 0.29172251588999554,
#  '발가락': 0.3740634121925842,
#  '짜증나면': 0.3035925268309837,
#  '받아들여': 0.3715937074979341,
#  '열일하': 0.1,
#  '빌게요': 0.26752064901163214,
#  '화보고온': 0.15445639406730824,
#  '시달리고': 0.12651412414296712,
#  '하겠네요': 0.3319557761763507,
#  '쿨하게': 1.4482378986989932,
#  '쌉니다': 0.8406377643785,
#  '티비에': 0.3599647886045012,
#  '시점에선': 0.23212216237036623,
#  '정도라면': 0.2603969423663174,
#  '새끼고양이': 0.1,
#  '붉어지': 0.1,
#  '너무이쁘': 0.1,
#  '도와드': 0.13739225116353132,
#  '다르다고': 0.4953224159085764,
#  '악플로': 0.2582749028439799,
#  '도운이랑': 0.26761642206285335,
#  '적은게': 0.14226720663288517,
#  '잘어울리': 0.1,
#  '첫컷보': 0.1,
#  '족같은': 0.49494951281438826,
#  '영향을': 0.46292872618241554,
#  '라이징패스트': 0.1,
#  '욕먹': 0.3595668328928603,
#  '예상': 0.451848718839742,
#  '행복해보여': 0.1,
#  '혼란스럽다': 0.4173259337039589,
#  '한마디하': 0.1,
#  '셔츠': 1.576077234339208,
#  '베댓되면': 0.8439653579239321,
#  '같긴한데': 0.3765976080137965,
#  '난리치': 0.2032331398620511,
#  '칼리가': 0.6425595443697725,
#  '안봤으면': 0.18475018182642328,
#  '꼰대': 2.649963705338442,
#  '댓글달': 0.34112291699537023,
#  '대장장이': 0.1,
#  '연기하는거': 0.28427483383990704,
#  '천원짜': 0.1,
#  '건드리지': 0.3919098445853718,
#  '캐릭인': 0.1,
#  '평균이': 0.19092017740693754,
#  '이기겠지': 0.1545616176826768,
#  '현실을': 0.7041688412519286,
#  '옛날에도': 0.3780244120882109,
#  '전자오락수': 0.1,
#  '야부님': 0.40879238690349606,
#  '약한영': 0.1,
#  '선입견을': 0.2292998765051402,
#  '어른스러': 0.1642085892433465,
#  '태진이': 0.43437627176140425,
#  '쐐기': 0.1,
#  '질질끈다는': 0.4091187985369027,
#  '며칠': 1.59517267981973,
#  '잘그리신다': 0.4509656599689441,
#  '대단하긴': 0.2172444147370772,
#  '데려다가': 0.31086870302104874,
#  '사실이잖': 0.1,
#  '그런거에': 0.16221568038093082,
#  '개사이다': 0.5812929940269571,
#  '간호사들': 0.1,
#  '문제없이': 0.27759590039945986,
#  '표현을': 0.6739440940655036,
#  '될거같네요': 0.6750699254536784,
#  '당연한겁니다': 0.4546481061532026,
#  '등장인물들의': 0.9679729114581488,
#  '영정사진': 0.1,
#  '숨어서': 0.5944492200139139,
#  '거리다가': 0.3550923196700896,
#  '머지않': 0.1,
#  '인물들을': 0.32591206941761036,
#  '먼저보': 0.1,
#  '받을까봐': 0.40964765205397025,
#  '덜떨어': 0.1,
#  '의미없': 0.20269085642054083,
#  '발목을': 0.16557489422103044,
#  '패스트': 0.1,
#  '경찰관': 0.14157747178029012,
#  '노블레스를': 0.4431397690683132,
#  '만화인데': 0.5787796619228792,
#  '괜찮으시': 0.1,
#  '걸리면': 0.6560792974676369,
#  '변태인': 0.1,
#  '달팽이': 0.3615583110408398,
#  '침착한': 0.28410885443216916,
#  '사람들임': 0.20476368614336138,
#  '피부병': 0.1366826702916908,
#  '마음아프': 0.17131576632389392,
#  '경우의': 0.23206900093370725,
#  '잘못했으': 0.1,
#  '워크래프트': 0.7363864614915148,
#  '맘스터': 0.1,
#  '복잡해': 0.14341655210064577,
#  '생각이라': 0.1,
#  '오예입니': 0.1,
#  '죽인': 0.2642032376335649,
#  '알바생': 0.21658855683549266,
#  '효과': 0.9653338276431624,
#  '아무리그래': 0.1,
#  '뚱땡': 0.1,
#  '저러는게': 0.2820318467140271,
#  '포기하고': 1.5152363303054563,
#  '치료제': 0.1795452783682424,
#  '아들에게': 0.3214121048887605,
#  '반장의': 0.22072555687887668,
#  '대립하는': 0.26922222529983453,
#  '안하는것': 0.1,
#  '낮은건': 0.32546319232591414,
#  '울컥했': 0.2682173495199769,
#  '올라옵니다': 0.45360292226950116,
#  '핏줄': 0.5272630480262921,
#  '유연이랑': 0.3269956106492555,
#  '쥔공이': 1.0239225619908627,
#  '노무현': 0.23923615331817485,
#  '도마뱀': 0.17964014763523106,
#  '짱인데': 0.23459837287020624,
#  '중입니다': 0.8555027696764558,
#  '술쳐먹': 0.1,
#  '끔살당': 0.1,
#  '뱀파이어는': 0.3720175893996617,
#  '돌려놓': 0.1,
#  '씹덕': 0.34805655018748016,
#  '전성기때': 0.20865700728346415,
#  '이래라저래': 0.1,
#  '부활남': 0.2578794260734615,
#  '레이널': 0.1,
#  '몇화만에': 0.34841133632368393,
#  '눈마주치': 0.1,
#  '여잔데': 0.30255184261247653,
#  '언제든지': 0.7211488191564783,
#  '카라': 0.1766070676228914,
#  '설정도': 0.321040110659309,
#  '알아야하는': 0.1,
#  '못할거같': 0.1,
#  '발전해': 0.15541826187298802,
#  '되고있어': 0.23208812713622373,
#  '폐기처': 0.1,
#  '만들어줘': 0.29844261315288145,
#  '게르망은': 0.30550070756344117,
#  '질투하고': 0.5473061386932835,
#  '지적하': 0.18415904753447493,
#  '패거리': 0.395424346917418,
#  '원하는대로': 0.8331412562964642,
#  '엑소가': 0.412781402827883,
#  '동화책': 0.16560459671835276,
#  '노숙자': 0.18899712580916556,
#  '쉽지가': 0.1,
#  '있어야한다': 0.23688196736090364,
#  '있을거에요': 0.45251880013755164,
#  '바뀌는거': 0.40069861538811047,
#  '갔더니': 0.6452581226426012,
#  '시까지': 0.31717215637790663,
#  '추천드': 0.1559941226863802,
#  '원하면': 0.25558763983467947,
#  '현재까지': 0.8013756087038372,
#  '장면인': 0.13072678723825287,
#  '망했는': 0.1,
#  '뿐인거': 0.14380866506238427,
#  '멈추면': 0.3497977985159324,
#  '웹툰이니': 0.29977949137600335,
#  '첫컷에': 0.5946520998212516,
#  '힘내십': 0.13665424514926136,
#  '추억하': 0.1,
#  '확인사살': 0.3534810469187153,
#  '침입': 0.13079612773534924,
#  '한동안': 0.32874429403226946,
#  '키워보': 0.1,
#  '때리고싶': 0.1,
#  '되겠다는': 0.20690637476205048,
#  '무시하지마라': 0.4516640453529931,
#  '예측해': 0.14913020084134854,
#  '왕자라': 0.1,
#  '만든다': 0.28570269372085244,
#  '영어이름': 0.22676235536751235,
#  '아무생각': 0.1681776603051253,
#  '은주한': 0.1,
#  '때문인': 0.3764933134494757,
#  '따라하는': 0.45346378545115396,
#  '윈드브': 0.1,
#  '마리아는': 0.26456575194261317,
#  '변태새': 0.1,
#  '혁진': 0.20754840758169577,
#  '흥미진진하다': 0.791304458115146,
#  '노호정': 0.13902963535482357,
#  '들어옴': 0.3225924005703351,
#  '고마운데': 0.2575932525422615,
#  '줬으면': 0.86829980600129,
#  '럭키짱보다': 0.7583628449251362,
#  '안나옴': 0.28541458153151744,
#  '어지간': 0.15373682022008067,
#  '괜찮다': 0.5350171632107972,
#  '반가운': 0.2060181416854533,
#  '앞으로': 2.396876713909101,
#  '눌렀': 0.18411793629261552,
#  '최순실': 0.36785592863531447,
#  '너무재밌어': 0.2780406908914743,
#  '스테로이': 0.1,
#  '판다독이랑': 0.5675438804382351,
#  '알아두세': 0.1,
#  '왜냐': 0.2325647344190611,
#  '우지영이': 0.15764394724238273,
#  '양미정': 0.2558169846815127,
#  '엔터테': 0.1,
#  '괴롭혀': 0.2931290677491345,
#  '넣으신': 0.33385103690733553,
#  '회사나': 0.19328437530065726,
#  '연재가': 0.3834644567915264,
#  '그래서인': 0.1,
#  '했더니': 0.9671216520594738,
#  '통조림': 0.19176051970977553,
#  '짝사랑하는': 1.1191530034322235,
#  '월요웹': 0.1,
#  '해당되는': 0.3651960879459203,
#  '소문으로': 0.25481518575352413,
#  '닮았고': 0.2713608474298467,
#  '반전이라': 0.1,
#  '카톡에': 0.16250053096504083,
#  '그나저': 0.1,
#  '비슷하': 0.4180148728718932,
#  '읽으시': 0.1,
#  '립스틱': 2.0173814659866913,
#  '닫으': 0.1,
#  '마더나이트가': 0.4302310322868719,
#  '꺼졌으면': 0.25917587030404793,
#  '희원이가': 0.5847587518255146,
#  '보여주자': 0.20282438949088694,
#  '다다다다': 0.1646749778081662,
#  '매력있다': 0.46156475184025736,
#  '살아계셨': 0.1,
#  '하얀머리': 0.24006322386421186,
#  '침입자': 0.1,
#  '댓글란': 0.11211331257466824,
#  '홍시는': 0.25596695121810753,
#  '얘긴데': 0.2693019706521403,
#  '동질감': 0.1,
#  '하시면': 0.2988416162536953,
#  '받았었': 0.1,
#  '답이다': 0.39432148256553134,
#  '앞치마': 0.162438614113874,
#  '헤아리': 0.1,
#  '교회다': 0.1,
#  '쿠키쓰': 0.1,
#  '멸망했': 0.1,
#  '때문이었': 0.1,
#  '놓아': 0.16028929667580344,
#  '잘하시': 0.18564362253667677,
#  '개잘생겼다': 0.2756289976317289,
#  '시리즈에': 0.16629518547652972,
#  '다행입니다': 0.48895250350129493,
#  '유지해': 0.1,
#  '손들고': 0.18758781649860903,
#  '여자애는': 0.5330416939555613,
#  '떠들어': 0.168357875366674,
#  '외부에': 0.1833583570250586,
#  '해주신': 0.26705421222940307,
#  '편하다': 0.38273966533079384,
#  '터미네': 0.1,
#  '작가보다': 0.25167315811907087,
#  '안되겠지': 0.18298668496632636,
#  '칠때': 0.28294658764437375,
#  '짜장면': 0.6577757205494816,
#  '할아버지인': 0.22674593561484857,
#  '많아지면': 0.2134823123672333,
#  '바름이가': 0.5844696210548475,
#  '가능성도': 0.36291772355515517,
#  '알아보지': 0.22005093514117385,
#  '확신하': 0.1768452039759656,
#  '짚어': 0.38035853014436016,
#  '끊는거': 0.37672695805048106,
#  '인과응보': 0.17173050548733426,
#  '익숙치': 0.1,
#  '꺼내기': 0.2114589297241778,
#  '모든것은': 0.31524266556058667,
#  '도와주지': 0.2338002506375678,
#  '싫다니': 0.1,
#  '떡밥이라고': 0.43751818151861765,
#  '함께한': 0.4225929155834387,
#  '인연이': 0.2550158853013183,
#  '환각을': 0.2151511480462846,
#  '빵점동': 0.1,
#  '이상하죠': 0.18844055846286076,
#  '진진돌이': 0.20321059457166968,
#  '드리겠습니': 0.1,
#  '주는거': 0.320895804368726,
#  '부족해서': 0.5705947943304759,
#  '그걸보고': 0.30161309010166826,
#  '영화도': 0.23942611207268272,
#  '잠입해': 0.1,
#  '개그만': 0.10762069350231585,
#  '평화로워': 0.3135265801191271,
#  '무서워하': 0.2476067983849374,
#  '질척거리': 0.1,
#  '이번화에도': 0.14935207886113838,
#  '집에와서': 0.42945329953710076,
#  '별점테러하는': 0.7825478271606856,
#  '사사로운': 0.18485418793400854,
#  '실마리': 0.1,
#  '올해는': 0.2518891290708363,
#  '얽히고': 0.5745844819369181,
#  '다운그레이드': 0.5018168220447116,
#  '피해자에': 0.14922800381064238,
#  '아이에게': 0.4853655065880429,
#  '말하지만': 0.5721252560928068,
#  '반토막': 0.1919599366137465,
#  '눈물을': 0.3746813491739951,
#  '미친놈이': 0.35482441925395547,
#  '하루하루가': 0.4545751219808668,
#  '레이널드가': 0.6976930870751022,
#  '알고있던': 0.16577786498582398,
#  '하는것입니': 0.1,
#  '갈등은': 0.2152657693012943,
#  '컴플레인': 0.6141609469597102,
#  '관광객': 0.14099840378232373,
#  '되어있어': 0.21238619857058455,
#  '킬더': 0.10997250679006787,
#  '화때부터': 0.44753614586309576,
#  '수치심을': 0.1579342109442574,
#  '근거가': 0.21296556018384344,
#  '성격을': 0.36689346028371084,
#  '자연재해': 0.1,
#  '고생많으': 0.1,
#  '냠냠': 2.228943765608085,
#  '복종하': 0.1,
#  '군대간': 0.1983116047512717,
#  '썰이': 0.22236471439822625,
#  '단점은': 0.2979895609429241,
#  '날에는': 0.3387522866119568,
#  '최현태님': 0.1683168281168168,
#  '이야기지만': 0.26446339142522535,
#  '저도': 0.42938361452800655,
#  '허락하': 0.1,
#  '차근차근': 0.6601508071044941,
#  '당연한거임': 0.48079628369984617,
#  '치료비': 0.2047340844053316,
#  '전문가들': 0.19754248045471298,
#  '임향희': 0.1887188942850529,
#  '우리누나': 0.1,
#  '동굴에': 0.15917630946365585,
#  '명복을빕': 0.1,
#  '못했는데': 0.8130104884110112,
#  '가족끼리': 0.3520150580482586,
#  '말입니': 0.12465981286905033,
#  '느낀거지': 0.1,
#  '씬이': 0.8991118643792386,
#  '눈치도': 0.26409529754206695,
#  '타블렛': 0.24603490611842035,
#  '품평하': 0.1,
#  '정신차리': 0.2953042821078551,
#  '요즘들어': 0.5286253704144283,
#  '고민하고': 0.5291786248036547,
#  '화동안': 0.25805700116450647,
#  '안올리는': 0.1,
#  '꾸미지': 0.1895475121662204,
#  '작품보다': 0.18948908034773382,
#  '봐보세': 0.1,
#  '지극정성': 0.1,
#  ...}

# %%
dataset=sqlcontext.read.parquet('hdfs://master:9000/user/hadoop/all_hangul_spark.parquet')
dataset.schema
# Out:
# StructType(List(StructField(title_id,IntegerType,true),StructField(episode_num,IntegerType,true),StructField(comment_num,IntegerType,true),StructField(sentence,StringType,true),StructField(registered_time,TimestampType,true)))

# %%
from pyspark.sql.functions import udf
tokenizer_udf=udf(tokenizer)
token_df=dataset.withColumn('tokens', tokenizer_udf(dataset.sentence)).select('title_id', 'episode_num', 'comment_num', 'tokens', 'registered_time')

# %%
token_df.write.parquet('hdfs://master:9000/user/hadoop/all_hangul_tokens')
# Out:
# +--------+-----------+-----------+--------------------+-------------------+
# |title_id|episode_num|comment_num|              tokens|    registered_time|
# +--------+-----------+-----------+--------------------+-------------------+
# |  112931|          0|          0|[정주행, 하시는, 분들, 추천...|2013-05-22 01:07:04|
# |  112931|          0|          1|[만, 렙이, 레이, 드, 못,...|2013-04-15 01:47:32|
# |  112931|          0|          2|[아랑소드, 용사, 시절, 에피...|2013-05-02 08:37:28|
# |  112931|          0|          3|[본격, 드래곤, 이, 자기, ...|2013-04-19 06:56:25|
# |  112931|          0|          4|[본격, 세계, 를구한, 드래곤...|2013-04-26 07:52:28|
# +--------+-----------+-----------+--------------------+-------------------+
# only showing top 5 rows
